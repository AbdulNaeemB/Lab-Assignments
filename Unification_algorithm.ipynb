# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdulNaeemB/Lab-Assignments/blob/main/Unification_algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=['a','b']
b=['x','y']
c=list()
for j in a:
  if j not in b:
    print("Allowed")
for i in range(0,2):
  if len(a)==len(b):
    if a[0]!=b[0] and a[1]!=b[1] and a[0]!=b[1] and a[1]!=b[0]:
      print(b[i]+"/"+a[i])
      d=[a[i],b[i]]
      c.append(d)
print(c)
# Out:
# Allowed
# Allowed
# x/a
# y/b
# [['a', 'x'], ['b', 'y']]
